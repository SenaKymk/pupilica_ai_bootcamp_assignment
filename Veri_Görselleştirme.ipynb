# %% [markdown]
# <a href="https://colab.research.google.com/github/SenaKymk/pupilica_ai_bootcamp_assignment/blob/main/Veri_G%C3%B6rselle%C5%9Ftirme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# kütüphaneleri import edelim
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# pythonda uyarıları kapatır
import warnings
warnings.filterwarnings("ignore")

# %%
# veriyi içe aktar
veri = pd.read_csv("olimpiyatlar_temizlenmis.csv")
veri.head()
# Out:
#                        isim cinsiyet   yas     boy   kilo           takim  \
# 0      Edgar Lindenau Aabye        M  34.0  182.48  95.62  Denmark/Sweden
# 1      Arvo Ossian Aaltonen        M  30.0  182.01  76.69         Finland
# 2      Arvo Ossian Aaltonen        M  30.0  177.00  75.00         Finland
# 3  Juhamatti Tapio Aaltonen        M  28.0  184.00  85.00         Finland
# 4   Paavo Johannes Aaltonen        M  28.0  175.00  64.00         Finland
#
#    uok   yil   sezon      sehir        spor  \
# 0  DEN  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948  Summer     London  Gymnastics
#
#                                  etkinlik madalya
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
# Saçılım grafiği çizmek için bir plot yapalım
def sacilimGrafik():
    sns.scatterplot(x='boy', y='kilo', data=veri)
    plt.title('Boy ve Kilo Dağılımı - Beyaz Izgara Tema')
    plt.show()
sacilimGrafik()

# %%
# seaborn stilleri
sns.set_style("white")
sacilimGrafik()

# %%
# seaborn stilleri
sns.set_style("darkgrid")
sacilimGrafik()

# %%
# seaborn stilleri ve dağılım gradiği
# son olarak beyaz ızgara teması ile devam edelim
sns.set_style("whitegrid")
sacilimGrafik()

# %%
# hue = sınıf ya da etiket olarak adlandırılabilir.
# scatter plot çizdirilirken hue'ye göre sınıflar farklı renklendirili
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri)
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()

# %% [markdown]
# saçılım grafiği - doğrusal regresyon yöntemi

# %%
# saçılım grafiği yapılır üzerine doğrusal regresyon yöntemi ile line fit işlemi gerçekleştirilir
# doğrusal regresyon makine öğrenmesinde anlatılacaktır.
sns.regplot(x='boy', y='kilo', data=veri, marker="+", scatter_kws={'alpha':0.2})
plt.title('Boy ve Kilo Dağılımı')
plt.show()

# %%
# Renk Paletleri
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette = "Set3")
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()

# %%
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette = "rocket")
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()

# %%
sns.lineplot(x='boy', y='kilo', data=veri)
plt.title('Boy ve Kilo')
plt.show()

# %%
sns.lineplot(x='boy', y='kilo', hue='cinsiyet', data=veri)
plt.title('Cinsiyete göre Boy ve Kilo')
plt.show()

# %% [markdown]
# ## Histogram
# * Histogram, gruplandırılmış bir veri dağılımının sütun grafiğiyle gösterimidir.
# * Tekrarlı sayılardan oluşan verilerin, uygulanan işlemlerden sonra önce tabloya, tablodan yararlanarak grafiğe aktarılması, yani veri gruplarının grafiğinin dikdörtgen sütunlar halinde gösterilmesidir.
