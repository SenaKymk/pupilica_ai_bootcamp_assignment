# %% [markdown]
# <a href="https://colab.research.google.com/github/SenaKymk/pupilica_ai_bootcamp_assignment/blob/main/pupilica_21Aral%C4%B1kOdev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt
veri = pd.read_csv("IRIS.csv")
veri
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure()
plt.hist(veri["sepal_length"], color = "red", alpha = 0.9, bins=20 , label = "sepal_length")
plt.hist(veri["petal_length"], color = "yellow", alpha = 0.9, bins=20 , label = "petal_length")

plt.ylabel("Frekans (Kaç adet olduğu)")
plt.xlabel("cm")
plt.legend()

# %%
"""subplots"""
fig, ax = plt.subplots(2,1) # 2 satir, 1 sutun
fig.suptitle("Ana baslik")
ax[0].plot(veri.sepal_length, color = "red") # ax'lerin sifirincisi ilk eksen birinci plot
ax[0].set_title("Sepal Length")
ax[0].set_xlabel("index")
ax[0].set_ylabel("cm")

ax[1].plot(veri.petal_length, color = "blue")
ax[1].set_title("Petal Length")
ax[1].set_xlabel("index")
ax[1].set_ylabel("cm")

fig.tight_layout()
fig.subplots_adjust(top = 0.85)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.subplot(2,2,1)  # 2 satir ve 2 sutundan olussun ve ben 1. plotu cizdiriyorum
plt.scatter([1,2,3,4],[4,6,8,2])
plt.title("alt grafık 1")


plt.subplot(2, 2, 2)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 2")


plt.subplot(2, 2, 3) # 2 satir ve 2 sutundan olussun ve ben 3. plotu cizdiriyorum
plt.hist([1, 2, 3, 4, 5, 6, 7, 8])
plt.title("Alt Grafik 3")


plt.subplot(2, 2, 4)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 4")

plt.show() # Grafikleri göster
